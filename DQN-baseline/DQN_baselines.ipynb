# %%
# !pip install swig --quiet
# !pip install gymnasium --quiet
# !pip install stable_baselines3 --quiet
# !pip install gymnasium[box2d] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/251b_final_project/andrew_colabs/'
# Out:
# /content/drive/.shortcut-targets-by-id/1RCyQOI1i_gXpHt3VOJnq2dG0-KSqMU10/251b_final_project/andrew_colabs

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

import os

save_dir = "./car_racing_dqn_baseline/car_racing_dqn1.zip"

# %%
# Create and wrap the environment
env = gym.make('CarRacing-v2', continuous=False)
env = Monitor(env)  # Wrap the environment with the Monitor wrapper
env = DummyVecEnv([lambda: env])  # Then wrap it in a dummy vectorized environment

# Initialize the agent
model = DQN('MlpPolicy', env, verbose=1, buffer_size=100000) #Buffer a tenth of default size; RAM limitations.

# total_iterations = 50
time_steps = 2e5
best_mean_reward = -float('inf')

model.learn(total_timesteps=time_steps, reset_num_timesteps=False, progress_bar=True)
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")

model.save(save_dir)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ---------------------------------------------------------------------------
# LiveError                                 Traceback (most recent call last)
# <ipython-input-6-e3c44abfcaff> in <cell line: 13>()
#      11 best_mean_reward = -float('inf')
#      12
# ---> 13 model.learn(total_timesteps=time_steps, reset_num_timesteps=False, progress_bar=True)
#      14 mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
#      15 print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/dqn/dqn.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     265         progress_bar: bool = False,
#     266     ) -> SelfDQN:
# --> 267         return super().learn(
#     268             total_timesteps=total_timesteps,
#     269             callback=callback,
#
# ...
