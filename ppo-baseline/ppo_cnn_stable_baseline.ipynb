# %%
# !pip install swig --quiet
# !pip install gymnasium --quiet
# !pip install stable_baselines3 --quiet
# !pip install gymnasium[box2d] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 54.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 87.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for box2d-py (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/251b_final_project/jason_colabs/' # changed last to respective folder
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/251b_final_project/jason_colabs/ # changed last to respective folder'
# /content

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

save_dir = '/content/drive/MyDrive/251b_final_project/jason_colabs/'
model_dir = os.path.join(save_dir, 'car_racing_ppo_cnn_10epochs')

# %%
# Create the environment
env = gym.make('CarRacing-v2')
env = DummyVecEnv([lambda: env])  # Wrap in a dummy vectorized environment

# Initialize the agent
model = PPO("CnnPolicy", env, verbose=1)

total_iterations = 10 # change epochs here
time_steps = 10000
best_mean_reward = -float('inf')

# for iteration in range(total_iterations):
#     print(f"Training epoch: {iteration + 1}/{total_iterations}") # Changed 'iteration' to 'epoch'
#     model.learn(total_timesteps=time_steps, reset_num_timesteps=False)

#     mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
#     print(f"Iteration: {iteration + 1}, Mean reward: {mean_reward}, Std reward: {std_reward}")

#     if mean_reward > best_mean_reward:
#         best_mean_reward = mean_reward
#         model.save(model_dir)
#         print(f"Model saved at iteration {iteration + 1}")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
#printing the model architecture being used:
print(model.policy)
# Out:
# ActorCriticCnnPolicy(
#   (features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential()
#     (value_net): Sequential()
#   )
#   (action_net): Linear(in_features=512, out_features=3, bias=True)
#   (value_net): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
# start training

for iteration in range(total_iterations):
    print(f"Training epoch: {iteration + 1}/{total_iterations}") # Changed 'iteration' to 'epoch'
    model.learn(total_timesteps=time_steps, reset_num_timesteps=False)

    mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
    print(f"Iteration: {iteration + 1}, Mean reward: {mean_reward}, Std reward: {std_reward}")

    if mean_reward > best_mean_reward:
        best_mean_reward = mean_reward
        model.save(model_dir)
        print(f"Model saved at epoch {iteration + 1}") # changed 'iteration' to 'epoch'
# Out:
# Training epoch: 1/10
# -----------------------------
# | time/              |      |
# |    fps             | 78   |
# |    iterations      | 1    |
# |    time_elapsed    | 26   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 2           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005364764 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.0146      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.167       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00433    |
# |    std                  | 1           |
# |    value_loss           | 0.547       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 75           |
# |    iterations           | 3            |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0077945823 |
# |    clip_fraction        | 0.0848       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0753       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.211        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.993        |
# |    value_loss           | 0.442        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012068663 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.989       |
# |    value_loss           | 0.452       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 5           |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010726335 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0981      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.991       |
# |    value_loss           | 0.459       |
# -----------------------------------------
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Iteration: 1, Mean reward: 123.42110153064132, Std reward: 115.69818808100243
# Model saved at iteration 1
# Training epoch: 2/10
# ------------------------------
# | time/              |       |
# |    fps             | 73    |
# |    iterations      | 1     |
# |    time_elapsed    | 27    |
# |    total_timesteps | 12288 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014383594 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0815      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.987       |
# |    value_loss           | 0.438       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 3          |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01237206 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.238      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0452     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0141    |
# |    std                  | 0.986      |
# |    value_loss           | 0.278      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 4          |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01654905 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.2       |
# |    explained_variance   | 0.177      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0804     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.022     |
# |    std                  | 0.979      |
# |    value_loss           | 0.31       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 5           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017456774 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0802      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.971       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# Iteration: 2, Mean reward: -83.71678940504789, Std reward: 70.80370956085211
# Training epoch: 3/10
# ------------------------------
# | time/              |       |
# |    fps             | 82    |
# |    iterations      | 1     |
# |    time_elapsed    | 24    |
# |    total_timesteps | 22528 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014784007 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0228      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.946       |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 3           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017077927 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0119      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.93        |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019075949 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.039       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.916       |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 5           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.027608424 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0357     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.904       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# Iteration: 3, Mean reward: -18.777901977300644, Std reward: 11.388048419434638
# Training epoch: 4/10
# ------------------------------
# | time/              |       |
# |    fps             | 79    |
# |    iterations      | 1     |
# |    time_elapsed    | 25    |
# |    total_timesteps | 32768 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.020916887 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0347      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.881       |
# |    value_loss           | 0.283       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 3           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.024651263 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0132      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.873       |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 4           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025347807 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0212      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.867       |
# |    value_loss           | 0.242       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 5          |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02714677 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.81      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0375    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0289    |
# |    std                  | 0.865      |
# |    value_loss           | 0.139      |
# ----------------------------------------
# Iteration: 4, Mean reward: -37.95774213820696, Std reward: 6.548341793585964
# Training epoch: 5/10
# ------------------------------
# | time/              |       |
# |    fps             | 83    |
# |    iterations      | 1     |
# |    time_elapsed    | 24    |
# |    total_timesteps | 43008 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03179829 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.76      |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00271    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.035     |
# |    std                  | 0.847      |
# |    value_loss           | 0.177      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 3           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023473218 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00702     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.839       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.034765102 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0323      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0338     |
# |    std                  | 0.833       |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.026444819 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00066     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.822       |
# |    value_loss           | 0.164       |
# -----------------------------------------
# Iteration: 5, Mean reward: -21.08928650841117, Std reward: 18.77719895894299
# Training epoch: 6/10
# ------------------------------
# | time/              |       |
# |    fps             | 79    |
# |    iterations      | 1     |
# |    time_elapsed    | 25    |
# |    total_timesteps | 53248 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.042408798 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0539     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.039      |
# |    std                  | 0.801       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 3          |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03928991 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | 0.313      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.192      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0361    |
# |    std                  | 0.79       |
# |    value_loss           | 0.536      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.038746003 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00646     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0348     |
# |    std                  | 0.784       |
# |    value_loss           | 0.264       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 5           |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.036128156 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0344     |
# |    std                  | 0.777       |
# |    value_loss           | 0.294       |
# -----------------------------------------
# Iteration: 6, Mean reward: 64.1235808365047, Std reward: 189.81471135914688
# Training epoch: 7/10
# ------------------------------
# | time/              |       |
# |    fps             | 79    |
# |    iterations      | 1     |
# |    time_elapsed    | 25    |
# |    total_timesteps | 63488 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 2           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.038315363 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000422    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0367     |
# |    std                  | 0.762       |
# |    value_loss           | 0.224       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 3           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.042789765 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00338     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0413     |
# |    std                  | 0.749       |
# |    value_loss           | 0.178       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 4           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.036890168 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 0.741       |
# |    value_loss           | 0.783       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 5           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.059716742 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0358     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0395     |
# |    std                  | 0.729       |
# |    value_loss           | 0.212       |
# -----------------------------------------
# Iteration: 7, Mean reward: 71.72737368494272, Std reward: 139.4680116171298
# Training epoch: 8/10
# ------------------------------
# | time/              |       |
# |    fps             | 82    |
# |    iterations      | 1     |
# |    time_elapsed    | 24    |
# |    total_timesteps | 73728 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 2          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.05715037 |
# |    clip_fraction        | 0.36       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0745     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0318    |
# |    std                  | 0.719      |
# |    value_loss           | 0.646      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.038652703 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.425       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.714       |
# |    value_loss           | 1.72        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.032584563 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.294       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.711       |
# |    value_loss           | 1.67        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.054840796 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.515       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.708       |
# |    value_loss           | 2.27        |
# -----------------------------------------
# Iteration: 8, Mean reward: 351.38008273020387, Std reward: 172.8132304671854
# Model saved at iteration 8
# Training epoch: 9/10
# ------------------------------
# | time/              |       |
# |    fps             | 79    |
# |    iterations      | 1     |
# |    time_elapsed    | 25    |
# |    total_timesteps | 83968 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 77         |
# |    iterations           | 2          |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.06360012 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.69       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.374      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0297    |
# |    std                  | 0.703      |
# |    value_loss           | 1.39       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 3          |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.06518338 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.697      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.505      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0222    |
# |    std                  | 0.7        |
# |    value_loss           | 1.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 4          |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.08641208 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.208      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.02      |
# |    std                  | 0.692      |
# |    value_loss           | 1.85       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 5          |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.05234115 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.379      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0149    |
# |    std                  | 0.691      |
# |    value_loss           | 2.55       |
# ----------------------------------------
# Iteration: 9, Mean reward: 297.64591527059673, Std reward: 70.27091654645035
# Training epoch: 10/10
# ------------------------------
# | time/              |       |
# |    fps             | 82    |
# |    iterations      | 1     |
# |    time_elapsed    | 24    |
# |    total_timesteps | 94208 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 2          |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.05280102 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.71       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.011     |
# |    std                  | 0.676      |
# |    value_loss           | 2.17       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 3          |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.07586287 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.126      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0207    |
# |    std                  | 0.675      |
# |    value_loss           | 1.43       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 4           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.040412605 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.355       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.676       |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 5           |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.048650768 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.32        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.675       |
# |    value_loss           | 3.23        |
# -----------------------------------------
# Iteration: 10, Mean reward: 253.7905996322632, Std reward: 106.41690633428358

# %%
# import os
# save_dir = '/content/drive/MyDrive/CSE_251b/CSE_251b_Final_project/Dima_colabs/'
# model_dir = os.path.join(save_dir, 'car_racing_ppo')
# model.save(model_dir)

# %% [markdown]
# ## Try a new architecture
